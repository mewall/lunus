# %% [markdown]
# # Preparation of Molecular-dynamics Simulations of Protein Crystals
#
# $\text{David Wych}^{1,2}, \text{Michael E. Wall}^{1}$
#
# 1. Computer, Computational and Statistical Sciences Division, Los Alamos National Laboratory, Los Alamos, NM 87545, USA
# 2. Center for Nonlinear Studies, Los Alamos National Laboratory, Los Alamos, NM 87545, USA

# %%
import cctbx
import iotbx.pdb
import numpy as np
import itertools
import nglview as ngl
import parmed as pmd
import subprocess

# %% [markdown]
# *Note: we use ```![command]``` syntax throughtout this notebook to run `[command]` as though we were running it from the command line in the directory that we launched this notebook from. Other commands are `python` code that you can interpret as being run from short `python` scripts.*
#
# *Also Note: if you try to run this whole notebook using `Kernel > Restart & Run All` or `Cell > Run All` or something similar in the menu bar above, not that the `nglview` widgets will not show the visualizations until the kernel is interrupted, or until every code block has run. If the `nglview` widgets are empty or haven't spawned a window, make sure that no other code block is running, and run those code block again.*

# %% [markdown]
# ### Preparing a structural model: missing atoms and residues

# %% [markdown]
# The protein we're going to be working with is *staphylococcal nuclease*, a protein that digests single stranded nucleic acids.
#
# The structure for *staph. nuclease* were going to use is the PDB structure with pdbid `4WOR`.
#
# This structure has a calcium ion and a ligand (thymidine-3'-5'-diphosphate or "pdTp") bound to the active site.
#
# You can explore the structure in the window below. The secondary structure of the protein is shown in the ribbon diagram, the full atomic structure is shown in a semi-transparent ball-and-stick representation.
#
# The pdTp and calcium are shown in ball and stick. You can zoom in and out, and move the structure around by pressing `ctrl` (or holding down right-click on the mouse) and dragging.

# %%
view = ngl.show_structure_file("./files/4wor.pdb")
view.clear_representations()
view.add_cartoon("protein")
view.add_ball_and_stick("not protein and not water")
view.add_licorice("protein", opacity=0.3)
view
# Out:
# NGLWidget()

# %% [markdown]
# That is a representation of the **coordinates** of all the atoms, contained in the `.pdb` file, but in order to simulate the protein using Molecular Dynamics (MD) we're going to need to give those atoms properties, like mass, charge, and van der Waals radii, and bonded properties like bond stiffness and dihedral angle constraints, etc.

# %% [markdown]
# ### Forcefields: choices and parametrization
#
# The aforementioned properties are determined by the "forcefield", which is a name given the full set of parameters describing the preperties of the atoms.
#
# The force field we're going to use for the protein is the `AMBER99SB-ildn` force field. This force field also comes bundled with the `tip3p` parameter set for the waters and parameters for ions, like the calcium in the active site.
#
# We are going to have to parameterize the pdTp molecule separately.
#
# Let's separate out the pdTp atoms, so that we can parametrize them separately.

# %%
# read the full structure file
with open("./files/4wor.pdb", 'r') as input_file:
    # open up another .pdb file to write to (for the protein + Ca ion)
    with open("protein_calcium.pdb", 'w') as output_file_prot:
        # ... and another for the pdTp molecule
        with open("pdTp.pdb", 'w') as output_file_pdTp:
            lines = input_file.readlines()                
            for line in lines:
                # the resname for the pdTp molecule is "THP"
                if line[:6] == "HETATM" and "THP" in line:
                    output_file_pdTp.write(line)
                else:
                    # write everyting else but the waters to the protein
                    # and calcium .pdb file
                    if not "HOH" in line:
                        output_file_prot.write(line)

# %% [markdown]
# The ligand is a molecule of **thymidine-3',5'-diphosphate**, also known as **"pdTp"**, which acts as an inhibitor to the protein's normal substrate, which is single stranded DNA/RNA.

# %%
view = ngl.show_structure_file("pdTp.pdb")
view
# Out:
# NGLWidget()

# %% [markdown]
# A few things make parametrization of arbitrary small molecules difficult:
#
# - Chemistry is hard. It's, like, a whole field.
#     - For that reason, things like $\text{pK}_a$ / protonation states and molecular geometry are extremely hard to predict, just given a molecule, starting from scratch.
# - Quantum mechanics (QM) is also hard, but we need to do QM to get things truly right.
#     - To get the partial charges of the atoms, we need to know how the electrons are distributed around the molecule, which comes down (ultimately) to quantum mechanics.
#
# Thankfully, smart people (countless nameless graduate students over decades) have found workarounds.
#
# There are a variety of ways to parametrize a small molecule, but this task is so important and so common that there exist webservers that will do it for you!
#
# I used the webserver [SwissParam](http://localhost:8889/notebooks/swissparam.ch) to generate all the files present in the `pdTp/` directory that accompanies this notebook (after first adding hydrogens with UCSF `Chimera`'s `Structure Editing > AddH` tool.

# %% [markdown]
# Next we're going to process the protein and calcium atoms with `pdb4amber`, which adds on atoms that might be missing from residues, and caps off the N- and C-termini.

# %%
# !pdb4amber -i protein_calcium.pdb -o protein_calcium_amber.pdb --add-missing-atoms
# !mkdir pdb4amber_files; mv protein_calcium_amber_* pdb4amber_files
# Out:
# ==================================================
# Summary of pdb4amber for: protein_calcium.pdb
# ===================================================
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2062 and/or 2106 to connect. Line: CONECT 2062 2106
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2063 and/or 2064 to connect. Line: CONECT 2063 2064 2065 2066 2071
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2064 and/or 2063 to connect. Line: CONECT 2064 2063
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2065 and/or 2063 to connect. Line: CONECT 2065 2063
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2066 and/or 2062 to connect. Line: CONECT 2066 2062 2063
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2067 and/or 2068 to connect. Line: CONECT 2067 2068 2069 2070 2076
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2068 and/or 2067 to connect. Line: CONECT 2068 2067
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2069 and/or 2067 to connect. Line: CONECT 2069 2067
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2070 and/or 2067 to connect. Line: CONECT 2070 2067
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2071 and/or 2063 to connect. Line: CONECT 2071 2063 2072
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2072 and/or 2071 to connect. Line: CONECT 2072 2071 2073 2088 2089
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2073 and/or 2072 to connect. Line: CONECT 2073 2072 2074 2075 2090
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2074 and/or 2073 to connect. Line: CONECT 2074 2073 2078
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2075 and/or 2073 to connect. Line: CONECT 2075 2073 2076 2077 2091
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2076 and/or 2067 to connect. Line: CONECT 2076 2067 2075
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2077 and/or 2075 to connect. Line: CONECT 2077 2075 2078 2092 2093
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2078 and/or 2074 to connect. Line: CONECT 2078 2074 2077 2079 2094
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2079 and/or 2078 to connect. Line: CONECT 2079 2078 2080 2087
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2080 and/or 2079 to connect. Line: CONECT 2080 2079 2081 2082
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2081 and/or 2080 to connect. Line: CONECT 2081 2080
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2082 and/or 2080 to connect. Line: CONECT 2082 2080 2083
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2083 and/or 2082 to connect. Line: CONECT 2083 2082 2084 2085
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2084 and/or 2083 to connect. Line: CONECT 2084 2083
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2085 and/or 2083 to connect. Line: CONECT 2085 2083 2086 2087
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2086 and/or 2085 to connect. Line: CONECT 2086 2085
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2087 and/or 2079 to connect. Line: CONECT 2087 2079 2085 2095
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2088 and/or 2072 to connect. Line: CONECT 2088 2072
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2089 and/or 2072 to connect. Line: CONECT 2089 2072
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2090 and/or 2073 to connect. Line: CONECT 2090 2073
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2091 and/or 2075 to connect. Line: CONECT 2091 2075
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2092 and/or 2077 to connect. Line: CONECT 2092 2077
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2093 and/or 2077 to connect. Line: CONECT 2093 2077
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2094 and/or 2078 to connect. Line: CONECT 2094 2078
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2095 and/or 2087 to connect. Line: CONECT 2095 2087
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:725: PDBWarning: CONECT record - could not find atoms 2106 and/or 2062 to connect. Line: CONECT 2106 2062
#
#   warnings.warn('CONECT record - could not find atoms %d and/or %d to connect. Line: %s' %
# /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/lib/python3.10/site-packages/parmed/formats/pdb.py:763: PDBWarning: Could not find link atoms AtomLookupKey(name='CA', number=None, residue_name='CA', residue_number='201', chain='A', insertion_code='', segment_id='', alternate_location=None) and AtomLookupKey(name='O6P', number=None, residue_name='THP', residue_number='202', chain='A', insertion_code='', segment_id='', alternate_location=None)
#   warnings.warn('Could not find link atoms %s and %s' % (key1, key2), PDBWarning)
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# LYS_1 misses 4 heavy atom(s)
# HIS_3 misses 5 heavy atom(s)
# LYS_23 misses 3 heavy atom(s)
# GLN_25 misses 4 heavy atom(s)
# LYS_40 misses 5 heavy atom(s)
# HIS_41 misses 6 heavy atom(s)
# LYS_43 misses 5 heavy atom(s)
# LYS_44 misses 4 heavy atom(s)
# LYS_48 misses 4 heavy atom(s)
# LYS_59 misses 3 heavy atom(s)
# LYS_105 misses 2 heavy atom(s)
# LYS_111 misses 3 heavy atom(s)
# LYS_128 misses 3 heavy atom(s)
# LYS_129 misses 3 heavy atom(s)

# %% [markdown]
# Then we're going to use `GROMACS`'s `pdb2gmx` to generate a topology file for the protein and calcium file, using `AMBER14SB` forcefield, and making sure that the parameters for the water come along with. The flag ignh makes sure that gromacs ignores any hygrogens that might be in the file, and places in hydrogens of its own (just to make sure `GROMACS` stays happy).

# %%
# !gmx pdb2gmx -f protein_calcium_amber.pdb -o protein_calcium_gmx.pdb -p protein.top --water spce --ff amber99sb-ildn -ignh
# Out:
#                :-) GROMACS - gmx pdb2gmx, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx pdb2gmx -f protein_calcium_amber.pdb -o protein_calcium_gmx.pdb -p protein.top --water spce --ff amber99sb-ildn -ignh
#
# Using the Amber99sb-ildn force field in directory amber99sb-ildn.ff
#
# going to rename amber99sb-ildn.ff/aminoacids.r2b
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.r2b
#
# going to rename amber99sb-ildn.ff/dna.r2b
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/dna.r2b
#
# going to rename amber99sb-ildn.ff/rna.r2b
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/rna.r2b
# Reading protein_calcium_amber.pdb...
# Read '', 1093 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
#
# There are 2 chains and 0 blocks of water and 137 residues with 1093 atoms
#
#   chain  #res #atoms
#
#   1 ' '   136   1092
#
#   2 ' '     1      1
#
# All occupancies are one
# All occupancies are one
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/atomtypes.atp
#
# Reading residue database... (Amber99sb-ildn)
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.rtp
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/dna.rtp
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/rna.rtp
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.hdb
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/dna.hdb
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/rna.hdb
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.n.tdb
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.c.tdb
#
# Processing chain 1 (1092 atoms, 136 residues)
#
# Identified residue LYS1 as a starting terminus.
#
# Identified residue SER136 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Special Atom Distance matrix:
#                    MET21   MET27   MET60
#                    SD158   SD207   SD470
#    MET27   SD207   0.880
#    MET60   SD470   2.129   2.030
#    MET93   SD736   2.268   1.818   0.967
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.arn
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/dna.arn
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/rna.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 136 residues with 2226 atoms
# Chain time...
#
# Making bonds...
#
# Number of bonds was 2248, now 2247
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 5932 pairs
# Before cleaning: 6154 dihedrals
#
# Making cmap torsions...
#
# There are 6154 dihedrals,  411 impropers, 4097 angles
#           5899 pairs,     2247 bonds and     0 virtual sites
#
# Total mass 15516.202 a.m.u.
#
# Total charge 10.000 e
#
# Writing topology
#
# Processing chain 2 (1 atoms, 1 residues)
#
# Residue CA137 has type 'Ion', assuming it is not linked into a chain.
#
# Problem with chain definition, or missing terminal residues. This chain does not appear to contain a recognized chain molecule. If this is incorrect, you can edit residuetypes.dat to modify the behavior.
# 8 out of 8 lines of specbond.dat converted successfully
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/aminoacids.arn
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/dna.arn
# Opening force field file /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/share/gromacs/top/amber99sb-ildn.ff/rna.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 1 residues with 1 atoms
# Chain time...
#
# Making bonds...
#
# No bonds
#
# Generating angles, dihedrals and pairs...
#
# Making cmap torsions...
#
# There are    0 dihedrals,    0 impropers,    0 angles
#              0 pairs,        0 bonds and     0 virtual sites
#
# Total mass 40.080 a.m.u.
#
# Total charge 2.000 e
#
# Writing topology
#
# Including chain 1 in system: 2226 atoms 136 residues
#
# Including chain 2 in system: 1 atoms 1 residues
#
# Now there are 2227 atoms and 137 residues
#
# Total mass in system 15556.282 a.m.u.
#
# Total charge in system 12.000 e
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: protein_calcium_amber.pdb.
#
# The Amber99sb-ildn force field and the spce water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "Your theory is crazy, but it's not crazy enough to be true." (Niels Bohr)

# %% [markdown]
# Now, we need to concatenate the protein and calcium structure with the structure of the ligand.
#
# We make sure that the structure file for the full assymetric unit has all the header information from `4wor.pdb` (so that cctbx can build the unit cell and supercell correctly).
#
# You'll notice there's a lot of (potentially) confusing junk in the code below. This junk is actually a cleverly disguised call for help: please, if you know how to code and want to do structural biology, please write good code. Make sure your files are outputting things in the standard way. Every program used for computational chemistry and structural biology outputs files in a different way, even though the format is meant to provide standardization.
#
# It's madenning.
#
# Anyway, read the comments if you really want to know what the code is doing.

# %%
with open("protein_calcium_gmx.pdb", 'r') as input_prot:
    with open("./files/4wor.pdb", 'r') as input_header:
        with open("pdTp/pdTp.pdb", 'r') as input_pdTp:
            with open("asymmetric_unit.pdb", 'w') as output_file:
                # store the header lines containing the "CRYST1" and "SCALE" records
                # needed for cctbx laters
                header_lines = [line for line in input_header.readlines() if line[:5] in ["CRYST", "SCALE"]]
                # store the lines for the protein, leaving out the "TITLE" and "MODEL"
                # records at the start and the "TER" and "ENDMDL" records at the end
                prot_lines = input_prot.readlines()[2:-2]
                # storing the atoms from the pdTp file
                pdTp_lines = [line for line in input_pdTp.readlines() if "ATOM" in line]
                # write the header
                for line in header_lines:
                    output_file.write(line)
                # write the protein+calcium atoms
                for line in prot_lines:
                    # making sure no waters present
                    if not "HOH" in line:
                        # for the calcium...
                        if "CA   CA" in line:
                            # put a "TER" record before
                            output_file.write("TER\n")
                            line = line[:21] + "A" + line[22:]
                            # to continue the atom indices from here...
                            index = int(line[7:11]) + 1
                            output_file.write(line)
                        else:
                            if line[:6] in ["ATOM  ", "HETATM"]:
                                # make every atom chain A
                                line = line[:21] + "A" + line[22:]
                                # add element info for hydgens
                                if "H" in line[12:16]:
                                    line = line[:77] + "H \n"
                            output_file.write(line)
                # write the pdTp atoms
                for line in pdTp_lines:
                    # get the element
                    if "H" in line[12:16]:
                        element = "H"
                    if "N" in line[12:16]:
                        element = "N"
                    if "C" in line[12:16]:
                        element = "C"
                    if "O" in line[12:16]:
                        element = "O"
                    if "P" in line[12:16]:
                        element = "P"
                    # make the resid 301, the chain A, and write the element on the end
                    line = line[:7] + str(index) + line[11:21] + "A 301" + line[26:72] + "     {}".format(element) + " \n"
                    index += 1
                    output_file.write(line)
                output_file.write("END\n")

# %% [markdown]
# Now, the topology file for the supercell will be the same as the topology file for the asymmetric unit, just with 31 extra copies of the `[moleculetype]` records appended, because there are 31 extra copies of the asymmetric unit in the supercell.
#
# So, to convert the `protein.top` file to the `supercell.top` file, we just need to tack those lines on to the end, in order.

# %%
with open("protein.top", 'r') as f:
    with open("supercell.top", 'w') as g:
        lines = f.readlines()
        # there's only protein and calcium in the moleculetype
        # record for the protein.top file, so the final two
        # lines are protein and calcium
        final_lines = [line for line in lines][-2:]
        for line in lines:
            # Making sure the reference to the pdTp parms goes
            # in the right place
            if "forcefield.itp" in line:
                g.write(line)
                g.write("#include \"pdTp/pdTp.itp\" \n")
            else:
                g.write(line)
        # add LIG moleculetype to the asymetric unit
        g.write("LIG                 1\n")
        # then add 31 copies
        for _ in range(31):
            for line in final_lines:
                g.write(line)
            g.write("LIG                 1\n")

# %% [markdown]
# ### Expanding the system using crysatlline symmetry
#
# Next, we construct a `cctbx` hierarchy object from the asymmetric unit `.pdb` file, and use the `crystal_symmetry` information in the `xray_structure` for `4WOR` to propagate the asymmetric unit to a unit cell.

# %%
input_pdb = iotbx.pdb.input(file_name="asymmetric_unit.pdb")
input_hierarchy = input_pdb.construct_hierarchy(sort_atoms=False)
xray_structure = iotbx.pdb.input(file_name="./files/4wor.pdb").xray_structure_simple()
unit_cell = input_hierarchy.expand_to_p1(xray_structure.crystal_symmetry())

# %% [markdown]
# Let's take a look at it!
#
# *Explore it for yourself, you can zoom in, clock on parts of the structure to focus there, click and drag to rotate the structure, ctrl+click and drag to translate the structure, etc. Try it out!*

# %%
view = ngl.show_iotbx(unit_cell)
view.clear_representations()
view.add_ball_and_stick("not protein")
view.add_cartoon("protein")
view.camera="orthographic"
view
# Out:
# NGLWidget()

# %% [markdown]
# We're going to need to use the unit cell length (A, B, C) and angle (alpha, beta, gamma) information to tile the unit cells to create a supercell

# %%
A, B, C, alpha, gamma, beta = xray_structure.crystal_symmetry().unit_cell().parameters()
space_group = xray_structure.crystal_symmetry().space_group_info().symbol_and_number()
print(f"    A: {A},  B: {B},   C: {C}, \nalpha: {alpha}, beta: {beta}, gamma: {gamma}\nspace group: {space_group}")
# Out:
#     A: 48.499,  B: 48.499,   C: 63.43,
# alpha: 90.0, beta: 90.0, gamma: 90.0
# space group: P 41 (No. 76)

# %% [markdown]
# To make sure the supercell structure files have the right information, we'll need to create another xray_structure.crystal_symmetry object that has the correct box length and angle information.
#
# In our case, the box will be twice the length of the unit cell in each direction, and we'll need to switch the space group to P1

# %%
supercell_uc = cctbx.uctbx.unit_cell(parameters=(2*A,2*B,2*C,90.0,90.0,90.0))
supercell_symmetry = cctbx.crystal.symmetry(unit_cell=supercell_uc, space_group_symbol="P1")
supercell_symmetry
# Out:
# crystal.symmetry(
#     unit_cell=(96.998, 96.998, 126.86, 90, 90, 90),
#     space_group_symbol="P 1"
#   )

# %% [markdown]
# ### Constructing a supercell
#
# So, we have a symmetry object for our future supercell structure, but first we have to *create the sturcture file*.
#
# Below is a function which constructs supercells given input of the unit cell and the number of copies of the unit cell along each direction we want to append to create the supercell:
#
# First we will need to construct the unit cell vectors. Below is an example of a general unit cell with side lengths A, B and B, and angles $\alpha$, $\beta$, and $\gamma$.
#
# In our case, $\alpha=\beta=\gamma=90^{\text{o}}$, so the unit cell vectors are simply the box lengths in the x-, y- and z-directions, but the following code will work for any unit cells, with any side lengths and angles.
#
# ![unit_cell_angles](./images/unit_cell_angles.png)

# %%
def construct_supercell(UC, xrs, n_cells):
    '''Constructs a supercell from a unit cell given a number of cells in each dimension
    
    Parameters
    ----------
    UC : iotbx_pdb_hierarchy_ext.root)
        cctbx hierarchy object for the unit cell
    
    xrs : cctbx.xray.structure.structure
        cctbx xray structure object for the unit cell
    
    n_cells : int or tuple
        If given an int, N -> NxNxN supercell
        If given a tuple, (X,Y,Z) -> XxYxZ supercell
    
    Returns
    -------
    supercell : iotbx_pdb_hierarchy_ext.root
        cctbx hierarchy object for the supercell
    '''
    
    #calculate the unit cell vectors from the xray_structure
    A, B, C, alpha, beta, gamma = xrs.crystal_symmetry().unit_cell().parameters()
    cg = np.cos(np.radians(gamma))
    sg = np.sin(np.radians(gamma))
    cb = np.cos(np.radians(beta))
    ca = np.cos(np.radians(alpha))
    c1 = (ca - cb * cg) / sg
    avec = [A, 0.0, 0.0]
    bvec = [B*cg, B*sg, 0.0]
    cvec = [C*cb, C*c1, C*np.sqrt(1 - cb*cb - c1*c1)]
    for vec in [avec, bvec, cvec]:
        for i in range(3):
            if np.isclose(vec[i], 0.0, atol=0.0001):
                vec[i] = 0.0
    avec = np.array(avec)
    bvec = np.array(bvec)
    cvec = np.array(cvec)
    
    # start with a copy of the unitcell
    supercell = UC.deep_copy()
    
    # create an index tuple for each unit cell
    # e.g. (1,1,0) for the unitcell tiled forward
    #    in the x- and y-directions but not in the
    #    z-direction
    if not isinstance(n_cells, tuple):
        cells = [el for el in itertools.product(range(n_cells),repeat=3)]
    else:
        cells = [el for el in itertools.product(range(n_cells[0]), range(n_cells[1]), range(n_cells[2]))]
    
    for uc_idx in cells:
        
        # leave the original unit cell alone
        if uc_idx != (0,0,0):
            
            # create a unit cell copy
            new_UC = UC.deep_copy()
            
            # add a unit cell length along the appropriate axes to each atom
            for atom in new_UC.atoms():
                disp = uc_idx[0]*avec + uc_idx[1]*bvec + uc_idx[2]*cvec
                atom.set_xyz(tuple(np.array(atom.xyz)+disp))
            
            # add the chains from the shifted unit cell to the supercell
            for model in new_UC.models():
                supercell.models()[0].transfer_chains_from_other(model)
                    
    return supercell

# %%
supercell = construct_supercell(unit_cell, xray_structure, 2)

# %% [markdown]
# Let's see how we did:

# %%
view = ngl.show_iotbx(supercell)
view.camera="orthographic"
view.add_ball_and_stick("not protein")
view
# Out:
# NGLWidget()

# %% [markdown]
# Looks pretty good to me!
# Let's write out this file as a `.pdb`.

# %%
supercell.write_pdb_file("supercell.pdb", crystal_symmetry=supercell_symmetry, anisou=False)

# %% [markdown]
# `GROMACS` doesn't need chain information, but it will be confused if residues in different proteins have the same resid, so we need to get rid of chainids and reset the resids in order:

# %%
with open("supercell.pdb", 'r') as f:
    with open("supercell_no_chains_renumbered.pdb", 'w') as g:
        lines = f.readlines()
        current_index = 1
        # the first out of order resid is the LIG with resid 301
        bad_index = 301
        for line in lines:
            if line[:4] == "ATOM":
                # Get rid of the chainids
                line = line[:20] + "  " + line[22:]
                # Find the current inex
                index = int(line[22:26])
                # If we're in the same residue
                if index == current_index:
                    pass
                # If we've arrived at the next residue
                else:
                    # Check to see if it's the next residue in order
                    if index == current_index + 1:
                        # Reset the current index
                        current_index += 1
                        # ... but otherwise do nothing, because it's fine
                    else:
                        # If it's not the next residue in order
                        # check to see if it's the bad index and
                        # reset the current
                        if not index == bad_index:
                            bad_index = int(line[22:26])
                            current_index += 1
                            line = line[:22] + "{:>4}".format(current_index+1) + line[26:]
                        else:
                            line = line[:22] + "{:>4}".format(current_index+1) + line[26:]
                
                g.write(line)
            else:
                g.write(line)

# %% [markdown]
# ### Solvent modeling
#
# Now, we're going to use gromacs tools to solvate and neutralize the system:
#
# `gmx solvate` adds waters to the system using pre-prepared small boxes of water that are tiled to cover the simulation box and then waters are culled if they overlap with waters already in the system.
#
# The flags are:
#
# `-cp` the protein structure (`.gro`) file
#
# `-cs` the water type to tile the box with
#
# `-p` the topology (`.top`) file

# %%
# !gmx solvate -cp supercell_no_chains_renumbered.pdb -cs spc216.gro -p supercell.top -o supercell_solvated.gro
# Out:
#                :-) GROMACS - gmx solvate, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx solvate -cp supercell_no_chains_renumbered.pdb -cs spc216.gro -p supercell.top -o supercell_solvated.gro
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 6x6x7 boxes
# Solvent box contains 130962 atoms in 43654 residues
# Removed 13887 solvent atoms due to solvent-solvent overlap
# Removed 66618 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms): 16819 residues
# Generated solvent containing 50457 atoms in 16819 residues
# Writing generated configuration to supercell_solvated.gro
#
# Output configuration contains 122937 atoms in 21235 residues
# Volume                 :     1193.58 (nm^3)
# Density                :     1180.69 (g/l)
# Number of solvent molecules:  16819
#
# Processing topology
# Adding line for 16819 solvent molecules with resname (SOL) to topology file (supercell.top)
#
# Back Off! I just backed up supercell.top to ./#supercell.top.1#
#
# GROMACS reminds you: "Computer system analysis is like child-rearing; you can do grievous damage, but you cannot ensure success." (Tom DeMarcho)

# %%
cell = pmd.load_file("supercell_solvated.gro")
view = ngl.show_parmed(cell)
view.clear_representations()
view.add_cartoon("protein")
view.add_ball_and_stick("water", opacity=0.5)
view.add_licorice("not protein and not water")
view.camera = "orthographic"
view
# Out:
# NGLWidget()

# %% [markdown]
# Looks good!
#
# Notice that the proteins extend out of the box, while the waters are contained within the box.
#
# This is a consequence of the periodic boundary conditions. The computer treats one edge of the box as equivalent to its opposite edge, and everything that extends beyond the edge of the box is wrapped around to the inside of the other side of the box, like exiting the edge of the screen in PacMan and appearing on the other side.
#
# There's only one more step that we need to take care of before we start the energy minimization process: neutralizing the system with ions.
#
# We'll do this with `gmx grompp` and `gmx genion`.
#
# `grompp` is the `GROMACS` "pre-processor", it takes in the structure (`.gro`) and topology (`.top`) files and outputs a `.tpr` file. These files are binary run input files that we'll construct again before we head in to simulation. The reason we need one now is that `GROMACS` needs to analyze the eletrostatics of the system to place ions in an intelligent way!
#
# `genion` is going to replace water molecules in the system with ions, but if it places ions too close to charged atoms in the system, the system could be too high energy when we place it in to minimization.
#
# The arguments to grompp are:
#
# `-f`: "molecular dynamics parameter" (`.mdp`) file specifying the type of simulation (in this case, the file is really a dummy file, because we're not really simulating anything)
#
# `-c`: the structure (.gro) file
#
# `-p`: the topology (.top) file
#
# `-o`: the name of the binary run input (.tpr) file
#
# The arguments to genion are:
#
# `-s`: the binary run input (.tpr) file
#
# `-p`: the topology (.top) file
#
# `-o`: the name of the output structure (.gro) file
#
# `-neutral` specifying that we want to neutralize the system with ions
#
# `-rmin`: allows us to reset the minimum distance between added groups (it will fail if we don't add this because it thinks the ions are too close together, but as you'll see it's fine).

# %%
# !gmx grompp -f mdp_files/ions.mdp -c supercell_solvated.gro -p supercell.top -o ions.tpr -maxwarn 5
# Out:
#                 :-) GROMACS - gmx grompp, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx grompp -f mdp_files/ions.mdp -c supercell_solvated.gro -p supercell.top -o ions.tpr -maxwarn 5
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file mdp_files/ions.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -21177436
#
# WARNING 1 [file pdTp.itp, line 10]:
#   Atomtype CB was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# WARNING 2 [file pdTp.itp, line 15]:
#   Atomtype CR was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# Generated 2628 of the 2628 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 2619 of the 2628 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file supercell.top, line 143]:
#   System has non-zero total charge: 288.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 3 [file supercell.top, line 143]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
# Analysing residue names:
# There are:  4352    Protein residues
# There are:    32        Ion residues
# There are:    32      Other residues
# There are: 16819      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 318351.00
#
# The largest distance between excluded atoms is 0.415 nm
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 84x84x108, spacing 0.115 0.115 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.16
#
# This run will generate roughly 10 Mb of data
#
# There were 2 notes
#
# There were 3 warnings
#
# GROMACS reminds you: "Beat On the Brat With a Baseball Bat" (The Ramones)

# %%
# !echo 17 | gmx genion -s ions.tpr -p supercell.top -o supercell_solvated_neutral.gro -neutral -rmin 0.4
# Out:
#                 :-) GROMACS - gmx genion, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx genion -s ions.tpr -p supercell.top -o supercell_solvated_neutral.gro -neutral -rmin 0.4
#
# Reading file ions.tpr, VERSION 2022.4-conda_forge (single precision)
# Reading file ions.tpr, VERSION 2022.4-conda_forge (single precision)
# Will try to add 0 NA ions and 288 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has 122937 elements
# Group     1 (        Protein) has 71232 elements
# Group     2 (      Protein-H) has 34944 elements
# Group     3 (        C-alpha) has  4352 elements
# Group     4 (       Backbone) has 13056 elements
# Group     5 (      MainChain) has 17440 elements
# Group     6 (   MainChain+Cb) has 21504 elements
# Group     7 (    MainChain+H) has 21664 elements
# Group     8 (      SideChain) has 49568 elements
# Group     9 (    SideChain-H) has 17504 elements
# Group    10 (    Prot-Masses) has 71232 elements
# Group    11 (    non-Protein) has 51705 elements
# Group    12 (            Ion) has    32 elements
# Group    13 (          Other) has  1216 elements
# Group    14 (             CA) has    32 elements
# Group    15 (            LIG) has  1216 elements
# Group    16 (          Water) has 50457 elements
# Group    17 (            SOL) has 50457 elements
# Group    18 (      non-Water) has 72480 elements
# Group    19 ( Water_and_ions) has 50489 elements
# Select a group: Selected 17: 'SOL'
# Number of (3-atomic) solvent molecules: 16819
#
# Processing topology
# Replacing 288 solute molecules in topology file (supercell.top)  by 0 NA and 288 CL ions.
#
# Back Off! I just backed up supercell.top to ./#supercell.top.2#
# Using random seed -19541283.
# Replacing solvent molecule 11687 (atom 107541) with CL
# Replacing solvent molecule 3273 (atom 82299) with CL
# Replacing solvent molecule 10374 (atom 103602) with CL
# Replacing solvent molecule 11787 (atom 107841) with CL
# Replacing solvent molecule 6459 (atom 91857) with CL
# Replacing solvent molecule 116 (atom 72828) with CL
# Replacing solvent molecule 9670 (atom 101490) with CL
# Replacing solvent molecule 6886 (atom 93138) with CL
# Replacing solvent molecule 9404 (atom 100692) with CL
# Replacing solvent molecule 5310 (atom 88410) with CL
# Replacing solvent molecule 15559 (atom 119157) with CL
# Replacing solvent molecule 7907 (atom 96201) with CL
# Replacing solvent molecule 10852 (atom 105036) with CL
# Replacing solvent molecule 3256 (atom 82248) with CL
# Replacing solvent molecule 9362 (atom 100566) with CL
# Replacing solvent molecule 7621 (atom 95343) with CL
# Replacing solvent molecule 8717 (atom 98631) with CL
# Replacing solvent molecule 6692 (atom 92556) with CL
# Replacing solvent molecule 10911 (atom 105213) with CL
# Replacing solvent molecule 3769 (atom 83787) with CL
# Replacing solvent molecule 12092 (atom 108756) with CL
# Replacing solvent molecule 138 (atom 72894) with CL
# Replacing solvent molecule 4491 (atom 85953) with CL
# Replacing solvent molecule 698 (atom 74574) with CL
# Replacing solvent molecule 15130 (atom 117870) with CL
# Replacing solvent molecule 16748 (atom 122724) with CL
# Replacing solvent molecule 4991 (atom 87453) with CL
# Replacing solvent molecule 15117 (atom 117831) with CL
# Replacing solvent molecule 16332 (atom 121476) with CL
# Replacing solvent molecule 10710 (atom 104610) with CL
# Replacing solvent molecule 5602 (atom 89286) with CL
# Replacing solvent molecule 10759 (atom 104757) with CL
# Replacing solvent molecule 7148 (atom 93924) with CL
# Replacing solvent molecule 14703 (atom 116589) with CL
# Replacing solvent molecule 15148 (atom 117924) with CL
# Replacing solvent molecule 1328 (atom 76464) with CL
# Replacing solvent molecule 9097 (atom 99771) with CL
# Replacing solvent molecule 6261 (atom 91263) with CL
# Replacing solvent molecule 10402 (atom 103686) with CL
# Replacing solvent molecule 1621 (atom 77343) with CL
# Replacing solvent molecule 5561 (atom 89163) with CL
# Replacing solvent molecule 16722 (atom 122646) with CL
# Replacing solvent molecule 15899 (atom 120177) with CL
# Replacing solvent molecule 9041 (atom 99603) with CL
# Replacing solvent molecule 16589 (atom 122247) with CL
# Replacing solvent molecule 10810 (atom 104910) with CL
# Replacing solvent molecule 8773 (atom 98799) with CL
# Replacing solvent molecule 6817 (atom 92931) with CL
# Replacing solvent molecule 16783 (atom 122829) with CL
# Replacing solvent molecule 1184 (atom 76032) with CL
# Replacing solvent molecule 4690 (atom 86550) with CL
# Replacing solvent molecule 16477 (atom 121911) with CL
# Replacing solvent molecule 12164 (atom 108972) with CL
# Replacing solvent molecule 11000 (atom 105480) with CL
# Replacing solvent molecule 1250 (atom 76230) with CL
# Replacing solvent molecule 4461 (atom 85863) with CL
# Replacing solvent molecule 11736 (atom 107688) with CL
# Replacing solvent molecule 6988 (atom 93444) with CL
# Replacing solvent molecule 992 (atom 75456) with CL
# Replacing solvent molecule 4090 (atom 84750) with CL
# Replacing solvent molecule 8504 (atom 97992) with CL
# Replacing solvent molecule 9550 (atom 101130) with CL
# Replacing solvent molecule 9613 (atom 101319) with CL
# Replacing solvent molecule 14058 (atom 114654) with CL
# Replacing solvent molecule 8065 (atom 96675) with CL
# Replacing solvent molecule 315 (atom 73425) with CL
# Replacing solvent molecule 8380 (atom 97620) with CL
# Replacing solvent molecule 13523 (atom 113049) with CL
# Replacing solvent molecule 16211 (atom 121113) with CL
# Replacing solvent molecule 15626 (atom 119358) with CL
# Replacing solvent molecule 8405 (atom 97695) with CL
# Replacing solvent molecule 16523 (atom 122049) with CL
# Replacing solvent molecule 15582 (atom 119226) with CL
# Replacing solvent molecule 5643 (atom 89409) with CL
# Replacing solvent molecule 8834 (atom 98982) with CL
# Replacing solvent molecule 10183 (atom 103029) with CL
# Replacing solvent molecule 5824 (atom 89952) with CL
# Replacing solvent molecule 15854 (atom 120042) with CL
# Replacing solvent molecule 2944 (atom 81312) with CL
# Replacing solvent molecule 11583 (atom 107229) with CL
# Replacing solvent molecule 16530 (atom 122070) with CL
# Replacing solvent molecule 4174 (atom 85002) with CL
# Replacing solvent molecule 5558 (atom 89154) with CL
# Replacing solvent molecule 9491 (atom 100953) with CL
# Replacing solvent molecule 4191 (atom 85053) with CL
# Replacing solvent molecule 15020 (atom 117540) with CL
# Replacing solvent molecule 5117 (atom 87831) with CL
# Replacing solvent molecule 13300 (atom 112380) with CL
# Replacing solvent molecule 1167 (atom 75981) with CL
# Replacing solvent molecule 653 (atom 74439) with CL
# Replacing solvent molecule 4440 (atom 85800) with CL
# Replacing solvent molecule 11718 (atom 107634) with CL
# Replacing solvent molecule 5733 (atom 89679) with CL
# Replacing solvent molecule 321 (atom 73443) with CL
# Replacing solvent molecule 10844 (atom 105012) with CL
# Replacing solvent molecule 14312 (atom 115416) with CL
# Replacing solvent molecule 12381 (atom 109623) with CL
# Replacing solvent molecule 16818 (atom 122934) with CL
# Replacing solvent molecule 12392 (atom 109656) with CL
# Replacing solvent molecule 12258 (atom 109254) with CL
# Replacing solvent molecule 7751 (atom 95733) with CL
# Replacing solvent molecule 5741 (atom 89703) with CL
# Replacing solvent molecule 14477 (atom 115911) with CL
# Replacing solvent molecule 3034 (atom 81582) with CL
# Replacing solvent molecule 5854 (atom 90042) with CL
# Replacing solvent molecule 8872 (atom 99096) with CL
# Replacing solvent molecule 16374 (atom 121602) with CL
# Replacing solvent molecule 1219 (atom 76137) with CL
# Replacing solvent molecule 12168 (atom 108984) with CL
# Replacing solvent molecule 10765 (atom 104775) with CL
# Replacing solvent molecule 14665 (atom 116475) with CL
# Replacing solvent molecule 14044 (atom 114612) with CL
# Replacing solvent molecule 10679 (atom 104517) with CL
# Replacing solvent molecule 12706 (atom 110598) with CL
# Replacing solvent molecule 13612 (atom 113316) with CL
# Replacing solvent molecule 8076 (atom 96708) with CL
# Replacing solvent molecule 10396 (atom 103668) with CL
# Replacing solvent molecule 16388 (atom 121644) with CL
# Replacing solvent molecule 8187 (atom 97041) with CL
# Replacing solvent molecule 5245 (atom 88215) with CL
# Replacing solvent molecule 8353 (atom 97539) with CL
# Replacing solvent molecule 162 (atom 72966) with CL
# Replacing solvent molecule 2965 (atom 81375) with CL
# Replacing solvent molecule 1360 (atom 76560) with CL
# Replacing solvent molecule 7671 (atom 95493) with CL
# Replacing solvent molecule 3758 (atom 83754) with CL
# Replacing solvent molecule 13966 (atom 114378) with CL
# Replacing solvent molecule 7182 (atom 94026) with CL
# Replacing solvent molecule 6818 (atom 92934) with CL
# Replacing solvent molecule 11900 (atom 108180) with CL
# Replacing solvent molecule 2182 (atom 79026) with CL
# Replacing solvent molecule 3800 (atom 83880) with CL
# Replacing solvent molecule 364 (atom 73572) with CL
# Replacing solvent molecule 14475 (atom 115905) with CL
# Replacing solvent molecule 15717 (atom 119631) with CL
# Replacing solvent molecule 3545 (atom 83115) with CL
# Replacing solvent molecule 15272 (atom 118296) with CL
# Replacing solvent molecule 5219 (atom 88137) with CL
# Replacing solvent molecule 3951 (atom 84333) with CL
# Replacing solvent molecule 10659 (atom 104457) with CL
# Replacing solvent molecule 8963 (atom 99369) with CL
# Replacing solvent molecule 10196 (atom 103068) with CL
# Replacing solvent molecule 2260 (atom 79260) with CL
# Replacing solvent molecule 11931 (atom 108273) with CL
# Replacing solvent molecule 6209 (atom 91107) with CL
# Replacing solvent molecule 10203 (atom 103089) with CL
# Replacing solvent molecule 13474 (atom 112902) with CL
# Replacing solvent molecule 2356 (atom 79548) with CL
# Replacing solvent molecule 4258 (atom 85254) with CL
# Replacing solvent molecule 13201 (atom 112083) with CL
# Replacing solvent molecule 16703 (atom 122589) with CL
# Replacing solvent molecule 12680 (atom 110520) with CL
# Replacing solvent molecule 7681 (atom 95523) with CL
# Replacing solvent molecule 5398 (atom 88674) with CL
# Replacing solvent molecule 13884 (atom 114132) with CL
# Replacing solvent molecule 7306 (atom 94398) with CL
# Replacing solvent molecule 11048 (atom 105624) with CL
# Replacing solvent molecule 12239 (atom 109197) with CL
# Replacing solvent molecule 2217 (atom 79131) with CL
# Replacing solvent molecule 13557 (atom 113151) with CL
# Replacing solvent molecule 7173 (atom 93999) with CL
# Replacing solvent molecule 3776 (atom 83808) with CL
# Replacing solvent molecule 16168 (atom 120984) with CL
# Replacing solvent molecule 7801 (atom 95883) with CL
# Replacing solvent molecule 3952 (atom 84336) with CL
# Replacing solvent molecule 8557 (atom 98151) with CL
# Replacing solvent molecule 2429 (atom 79767) with CL
# Replacing solvent molecule 2704 (atom 80592) with CL
# Replacing solvent molecule 15383 (atom 118629) with CL
# Replacing solvent molecule 1561 (atom 77163) with CL
# Replacing solvent molecule 11747 (atom 107721) with CL
# Replacing solvent molecule 4350 (atom 85530) with CL
# Replacing solvent molecule 7207 (atom 94101) with CL
# Replacing solvent molecule 4163 (atom 84969) with CL
# Replacing solvent molecule 7059 (atom 93657) with CL
# Replacing solvent molecule 3787 (atom 83841) with CL
# Replacing solvent molecule 11396 (atom 106668) with CL
# Replacing solvent molecule 10654 (atom 104442) with CL
# Replacing solvent molecule 5812 (atom 89916) with CL
# Replacing solvent molecule 15389 (atom 118647) with CL
# Replacing solvent molecule 7772 (atom 95796) with CL
# Replacing solvent molecule 7697 (atom 95571) with CL
# Replacing solvent molecule 9262 (atom 100266) with CL
# Replacing solvent molecule 7777 (atom 95811) with CL
# Replacing solvent molecule 7286 (atom 94338) with CL
# Replacing solvent molecule 9461 (atom 100863) with CL
# Replacing solvent molecule 3597 (atom 83271) with CL
# Replacing solvent molecule 6494 (atom 91962) with CL
# Replacing solvent molecule 14994 (atom 117462) with CL
# Replacing solvent molecule 4384 (atom 85632) with CL
# Replacing solvent molecule 1802 (atom 77886) with CL
# Replacing solvent molecule 8163 (atom 96969) with CL
# Replacing solvent molecule 11588 (atom 107244) with CL
# Replacing solvent molecule 1646 (atom 77418) with CL
# Replacing solvent molecule 10873 (atom 105099) with CL
# Replacing solvent molecule 11328 (atom 106464) with CL
# Replacing solvent molecule 15129 (atom 117867) with CL
# Replacing solvent molecule 5487 (atom 88941) with CL
# Replacing solvent molecule 12350 (atom 109530) with CL
# Replacing solvent molecule 7084 (atom 93732) with CL
# Replacing solvent molecule 3892 (atom 84156) with CL
# Replacing solvent molecule 494 (atom 73962) with CL
# Replacing solvent molecule 4239 (atom 85197) with CL
# Replacing solvent molecule 5806 (atom 89898) with CL
# Replacing solvent molecule 10430 (atom 103770) with CL
# Replacing solvent molecule 10587 (atom 104241) with CL
# Replacing solvent molecule 4759 (atom 86757) with CL
# Replacing solvent molecule 15475 (atom 118905) with CL
# Replacing solvent molecule 3060 (atom 81660) with CL
# Replacing solvent molecule 15461 (atom 118863) with CL
# Replacing solvent molecule 5106 (atom 87798) with CL
# Replacing solvent molecule 159 (atom 72957) with CL
# Replacing solvent molecule 7046 (atom 93618) with CL
# Replacing solvent molecule 9493 (atom 100959) with CL
# Replacing solvent molecule 15893 (atom 120159) with CL
# Replacing solvent molecule 5879 (atom 90117) with CL
# Replacing solvent molecule 8639 (atom 98397) with CL
# Replacing solvent molecule 5209 (atom 88107) with CL
# Replacing solvent molecule 12688 (atom 110544) with CL
# Replacing solvent molecule 14265 (atom 115275) with CL
# Replacing solvent molecule 13197 (atom 112071) with CL
# Replacing solvent molecule 12348 (atom 109524) with CL
# Replacing solvent molecule 15119 (atom 117837) with CL
# Replacing solvent molecule 13170 (atom 111990) with CL
# Replacing solvent molecule 14341 (atom 115503) with CL
# Replacing solvent molecule 11262 (atom 106266) with CL
# Replacing solvent molecule 4872 (atom 87096) with CL
# Replacing solvent molecule 13516 (atom 113028) with CL
# Replacing solvent molecule 16583 (atom 122229) with CL
# Replacing solvent molecule 6008 (atom 90504) with CL
# Replacing solvent molecule 493 (atom 73959) with CL
# Replacing solvent molecule 16572 (atom 122196) with CL
# Replacing solvent molecule 397 (atom 73671) with CL
# Replacing solvent molecule 15460 (atom 118860) with CL
# Replacing solvent molecule 3976 (atom 84408) with CL
# Replacing solvent molecule 1339 (atom 76497) with CL
# Replacing solvent molecule 3211 (atom 82113) with CL
# Replacing solvent molecule 12074 (atom 108702) with CL
# Replacing solvent molecule 6754 (atom 92742) with CL
# Replacing solvent molecule 3603 (atom 83289) with CL
# Replacing solvent molecule 16140 (atom 120900) with CL
# Replacing solvent molecule 13180 (atom 112020) with CL
# Replacing solvent molecule 11127 (atom 105861) with CL
# Replacing solvent molecule 163 (atom 72969) with CL
# Replacing solvent molecule 15434 (atom 118782) with CL
# Replacing solvent molecule 13760 (atom 113760) with CL
# Replacing solvent molecule 10442 (atom 103806) with CL
# Replacing solvent molecule 9740 (atom 101700) with CL
# Replacing solvent molecule 9577 (atom 101211) with CL
# Replacing solvent molecule 13751 (atom 113733) with CL
# Replacing solvent molecule 9677 (atom 101511) with CL
# Replacing solvent molecule 5754 (atom 89742) with CL
# Replacing solvent molecule 10991 (atom 105453) with CL
# Replacing solvent molecule 10382 (atom 103626) with CL
# Replacing solvent molecule 9846 (atom 102018) with CL
# Replacing solvent molecule 13488 (atom 112944) with CL
# Replacing solvent molecule 6843 (atom 93009) with CL
# Replacing solvent molecule 16795 (atom 122865) with CL
# Replacing solvent molecule 11777 (atom 107811) with CL
# Replacing solvent molecule 866 (atom 75078) with CL
# Replacing solvent molecule 11594 (atom 107262) with CL
# Replacing solvent molecule 9972 (atom 102396) with CL
# Replacing solvent molecule 1864 (atom 78072) with CL
# Replacing solvent molecule 13119 (atom 111837) with CL
# Replacing solvent molecule 15848 (atom 120024) with CL
# Replacing solvent molecule 1196 (atom 76068) with CL
# Replacing solvent molecule 6809 (atom 92907) with CL
# Replacing solvent molecule 3962 (atom 84366) with CL
# Replacing solvent molecule 7061 (atom 93663) with CL
# Replacing solvent molecule 14167 (atom 114981) with CL
# Replacing solvent molecule 4596 (atom 86268) with CL
# Replacing solvent molecule 12585 (atom 110235) with CL
# Replacing solvent molecule 4072 (atom 84696) with CL
# Replacing solvent molecule 13830 (atom 113970) with CL
# Replacing solvent molecule 10962 (atom 105366) with CL
# Replacing solvent molecule 29 (atom 72567) with CL
# Replacing solvent molecule 16430 (atom 121770) with CL
# Replacing solvent molecule 8106 (atom 96798) with CL
# Replacing solvent molecule 9489 (atom 100947) with CL
# Replacing solvent molecule 7901 (atom 96183) with CL
# Replacing solvent molecule 10381 (atom 103623) with CL
# Replacing solvent molecule 2478 (atom 79914) with CL
# Replacing solvent molecule 6322 (atom 91446) with CL
# Replacing solvent molecule 3920 (atom 84240) with CL
# Replacing solvent molecule 3249 (atom 82227) with CL
# Replacing solvent molecule 5301 (atom 88383) with CL
# Replacing solvent molecule 13465 (atom 112875) with CL
# Replacing solvent molecule 1493 (atom 76959) with CL
#
#
# GROMACS reminds you: "When doing HPC, don't communica" (Jim Demmel)

# %% [markdown]
# Let's see it:

# %%
cell = pmd.load_file("supercell_solvated_neutral.gro")
view = ngl.show_parmed(cell)
view.clear_representations()
view.add_cartoon("protein")
view.add_ball_and_stick("water", opacity=0.5)
view.add_spacefill("name CL")
view.add_licorice("not protein and not water")
view.camera = "orthographic"
view
# Out:
# NGLWidget()

# %% [markdown]
# ### Minimization
#
# The `.mdp` files specify the parameters for simulation. Check them out in the `mdp_files` folder.
#
# Here's what ours looks like for minimization:
#
# `min.mdp`
#
# ```
# ; Parameters describing what to do, when to stop and what to save
# integrator  = steep         ; Algorithm (steep = steepest descent minimization)
# emtol       = 1000.0        ; Stop minimization when the maximum force < 1000.0 kJ/mol/nm
# emstep      = 0.01          ; Minimization step size
# nsteps      = 1000          ; Maximum number of (minimization) steps to perform
#
# ; Parameters describing how to find the neighbors of each atom and how to calculate the interactions
# nstlist         = 1         ; Frequency to update the neighbor list and long range forces
# cutoff-scheme   = Verlet    ; Buffered neighbor searching
# ns_type         = grid      ; Method to determine neighbor list (simple, grid)
# coulombtype     = PME       ; Treatment of long range electrostatic interactions
# rcoulomb        = 1.0       ; Short-range electrostatic cut-off
# rvdw            = 1.0       ; Short-range Van der Waals cut-off
# pbc             = xyz       ; Periodic Boundary Conditions in all 3 dimensions
# ```
#
# The important bits here are the `integrator` and `nsteps` parameters. Our selections say to do 1000 steps of minimizaiton with the steepest descent algorithm.
#
# `gmx grompp` takes in the `.mdp` file (`-f`), the starting coordiantes file (`-c`), the topology file (`-p`) and the output file name (`-o`) which will be a (`.tpr`) file with everything necessary to run the minimization.
#
# `gmx mdrun` runs the minimization, with the `.tpr` file as input (`-s`) and a `-deffnm` flag setting the filenames for all the output files.

# %%
# !gmx grompp -f mdp_files/min.mdp -c supercell_solvated_neutral.gro -p supercell.top -o min_1.tpr -maxwarn 2
# Out:
#                 :-) GROMACS - gmx grompp, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx grompp -f mdp_files/min.mdp -c supercell_solvated_neutral.gro -p supercell.top -o min_1.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file mdp_files/min.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -1343226049
#
# WARNING 1 [file pdTp.itp, line 10]:
#   Atomtype CB was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# WARNING 2 [file pdTp.itp, line 15]:
#   Atomtype CR was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# Generated 2628 of the 2628 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 2619 of the 2628 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Excluding 1 bonded neighbours molecule type 'CL'
# Analysing residue names:
# There are:  4352    Protein residues
# There are:   320        Ion residues
# There are:    32      Other residues
# There are: 16531      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 317487.00
#
# The largest distance between excluded atoms is 0.415 nm
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 84x84x108, spacing 0.115 0.115 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.16
#
# This run will generate roughly 9 Mb of data
#
# There was 1 note
#
# There were 2 warnings
#
# GROMACS reminds you: "Millions saw the apple fall, Newton was the only one who asked why?" (Bernard Baruch)

# %%
# !gmx mdrun -s min_1.tpr -deffnm min_1
# Out:
#                 :-) GROMACS - gmx mdrun, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx mdrun -s min_1.tpr -deffnm min_1
#
# Compiled SIMD: SSE2, but for this host/run SSE4.1 might be better (see log).
# Reading file min_1.tpr, VERSION 2022.4-conda_forge (single precision)
# Using 1 MPI thread
# Using 10 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =         1000
#
# step 21: One or more water molecules can not be settled.
# Check for bad contacts and/or reduce the timestep if appropriate.
# Wrote pdb files with previous and current coordinates
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 1000.
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 1000 in 1001 steps.
# Potential Energy  = -1.6826528e+06
# Maximum force     =  9.4381318e+03 on atom 54940
# Norm of force     =  4.6442654e+01
#
# GROMACS reminds you: "Try to calculate the numbers that have been" (The Smoke Fairies)

# %%
# !mkdir minimization_1; mv min_1.* minimization_1

# %% [markdown]
# Now we use `GROMACS`s `energy` function to get the potential energy for our minimization.
#
# The `echo 11` passed to the `gmx energy` call tells `GROMACS` we want to select option 11 for the data output (the Potential).
#
# If you were running these commands yourself, you could just run the command from `gmx energy ...` on and you could interactively select the data output yourself to get any info you want.

# %%
# !echo 11 | gmx energy -f minimization_1/min_1.edr -o energy_1.xvg
# !mv energy_1.xvg minimization_1
# Out:
#                 :-) GROMACS - gmx energy, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx energy -f minimization_1/min_1.edr -o energy_1.xvg
#
# Opened minimization_1/min_1.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Proper-Dih.      4  Improper-Dih.
#   5  Per.-Imp.-Dih.   6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Vir-XX          14  Vir-XY          15  Vir-XZ          16  Vir-YX
#  17  Vir-YY          18  Vir-YZ          19  Vir-ZX          20  Vir-ZY
#  21  Vir-ZZ          22  Pres-XX         23  Pres-XY         24  Pres-XZ
#  25  Pres-YX         26  Pres-YY         27  Pres-YZ         28  Pres-ZX
#  29  Pres-ZY         30  Pres-ZZ         31  #Surf*SurfTen   32  T-rest
#
# Last energy frame read 792 time 1000.000
#
# Statistics over 1001 steps [ 0.0000 through 1000.0000 ps ], 1 data sets
# All statistics are over 793 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                7.51329e+07    7.6e+07 1.98864e+09 -4.5677e+08  (kJ/mol)
#
# GROMACS reminds you: "We Look Pretty Sharp In These Clothes" (F. Zappa)

# %% [markdown]
# We'll plot the data with `matplotlib`, python's standard plotting software, after a bit of data processing to get everything in a python friendly format.

# %%
import matplotlib.pyplot as plt

# %%
def get_data_from_xvg(filename):
    ''' helper function for getting data from .xvg files
    '''
    with open(filename) as f:
        x = []; y = []
        for line in f.readlines():
            # ignore the header lines with first character @ or #
            if line[0] not in ["#", "@"]:
                x.append(float(line.split()[0]))
                y.append(float(line.split()[1]))
    
    return np.array(x), np.array(y)

# %%
t, E = get_data_from_xvg("minimization_1/energy_1.xvg")
plt.plot(t, E)

# %% [markdown]
# Well, that looks funny.
#
# What's happening here is the energy is enormous to start, thanks to unfavorable interactions between the added solvent and ions and the protein, so it drops rapidly thanks to the steepest descent minimization.
#
# To get a better sense for what's going on, let's look at the change in energy from step to step, and plot it on the log scale:

# %%
def dE(time,energy):
    ''' helper function for getting changes in energy in absolute terms
    '''
    dE = []
    for i in range(len(t)-1):
        dE.append(energy[i+1]-energy[i])
        
    return t[1:], [abs(E) for E in dE]

# %%
plt.semilogy(dE(t,E)[0], dE(t,E)[1])
print("Average abs change in energy for the last 50 steps: {} kJ/mol".format(np.mean(dE(t,E)[-1][-50:])))
# Out:
# Average abs change in energy for the last 50 steps: 120.5275 kJ/mol

# %% [markdown]
# Now, we can see that, over the course of minimization, the energy has plateaud.

# %% [markdown]
# ### Adjusting the pressure via iterative solvation and equilibration
#
# Now we're going to do our first bits of actual molecular-dynamics simulation.
#
# Take a look at the `equil.mdp` file in the `mdp_files` directory to see the parameters we set for this, but the important bits are:
#
# `define = -DPOSRES`: puts restraints on the protein, ligand, and ions (all set to 1000 kJ/(moln m^2))
#
# `integrator = md`: use the leap-frog numerical integration algorithm
#
# `nsteps = 500`: do 500 total steps of simulation (500 steps * 0.002 fs/step = 1 ps)
#
# `dt = 0.002`: each with a time step of 2 fs (base units are ps)
#
# `nstxout`, `nstenergy`, etc `= 5`: sets the number of steps to wait before outputting coordinate and energy (etc.) information in their own respective files (in our case, 5 steps, so output every 10 fs (0.01 ps)
#
# The only new argument to grompp here is the `-r` which specfifies the coordinate file to use for the target for restraints.
#
# Here's we'll just use the solvated, neutralized crystal structure (`supercell_solvated_neutral.gro`).
#
# Always be sure this file has the same number of atoms as the coordiante file. Even if the number of atoms in the actually restrained part is the same, if there's a differnt number of solvent atoms, `GROMACS` will complain.

# %%
# !gmx grompp -f mdp_files/equil.mdp -c minimization_1/min_1.gro -p supercell.top -r supercell_solvated_neutral.gro -o equil_1.tpr -maxwarn 2
# Out:
#                 :-) GROMACS - gmx grompp, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx grompp -f mdp_files/equil.mdp -c minimization_1/min_1.gro -p supercell.top -r supercell_solvated_neutral.gro -o equil_1.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file mdp_files/equil.mdp]:
#   Setting nstcalcenergy (100) equal to nstenergy (5)
#
# Setting the LD random seed to -1613535317
#
# WARNING 1 [file pdTp.itp, line 10]:
#   Atomtype CB was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# WARNING 2 [file pdTp.itp, line 15]:
#   Atomtype CR was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# Generated 2628 of the 2628 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 2619 of the 2628 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# Setting gen_seed to 1052569499
#
# Velocities were taken from a Maxwell distribution at 300 K
# Analysing residue names:
# There are:  4352    Protein residues
# There are:   320        Ion residues
# There are:    32      Other residues
# There are: 16531      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group Protein is 177406.11
# Number of degrees of freedom in T-Coupling group non-Protein is 103376.90
#
# The largest distance between excluded atoms is 0.425 nm
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.023 nm, buffer size 0.023 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 2 [file mdp_files/equil.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 64x64x80, spacing 0.152 0.152 0.159
#
# Estimate for the relative computational load of the PME mesh part: 0.13
#
# This run will generate roughly 293 Mb of data
#
# There were 2 notes
#
# There were 2 warnings
# GROMACS reminds you: "I don't want to achieve immortality through my work... I want to achieve it through not dying!" (Woody Allen)

# %%
# !gmx mdrun -s equil_1.tpr -deffnm equil_1
# Out:
#                 :-) GROMACS - gmx mdrun, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx mdrun -s equil_1.tpr -deffnm equil_1
#
# Compiled SIMD: SSE2, but for this host/run SSE4.1 might be better (see log).
# Reading file equil_1.tpr, VERSION 2022.4-conda_forge (single precision)
# Changing nstlist from 10 to 100, rlist from 1 to 1.12
#
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# starting mdrun 'Protein in water'
# 500 steps,      1.0 ps.
#
# Writing final coordinates.
#
#                Core t (s)   Wall t (s)        (%)
#        Time:      235.442       23.544     1000.0
#                  (ns/day)    (hour/ns)
# Performance:        3.677        6.527
#
# GROMACS reminds you: "And You Will Know That My Name is the Lord When I Lay My Vengeance Upon Thee." (Pulp Fiction)

# %%
# !mkdir equilibration_1; mv equil_1.* equilibration_1

# %% [markdown]
# We use `gmx energy` again, this time feeding in the selection `19` for the pressure.

# %%
# !echo 19 | gmx energy -f equilibration_1/equil_1.edr -o equil_pressure_1.xvg
# !mv equil_pressure_1.xvg equilibration_1
# Out:
#                 :-) GROMACS - gmx energy, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx energy -f equilibration_1/equil_1.edr -o equil_pressure_1.xvg
#
# Opened equilibration_1/equil_1.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Proper-Dih.      4  Improper-Dih.
#   5  Per.-Imp.-Dih.   6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Disper.-corr.   10  Coulomb-(SR)    11  Coul.-recip.    12  Position-Rest.
#  13  Potential       14  Kinetic-En.     15  Total-Energy    16  Conserved-En.
#  17  Temperature     18  Pres.-DC        19  Pressure        20  Constr.-rmsd
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-Protein
#  41  T-non-Protein                       42  Lamb-Protein
#  43  Lamb-non-Protein
#
# Last energy frame read 100 time    1.000
#
# Statistics over 501 steps [ 0.0000 through 1.0000 ps ], 1 data sets
# All statistics are over 101 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   -1410.41        160    443.453    111.264  (bar)
#
# GROMACS reminds you: "And You Will Know That My Name is the Lord When I Lay My Vengeance Upon Thee." (Pulp Fiction)

# %%
def get_mean_and_std_error(T,P):
    ''' helper funciton for getting the mean and standard error
    '''
    std_error = []
    mean = []
    for i in range(len(T)-1):
        mean.append(np.mean(P[:i+1]))
        std_error.append(np.std(P[:i+1])/np.sqrt(i+1))
    
    return np.array(mean), np.array(std_error)

# %%
t, p1 = get_data_from_xvg("equilibration_1/equil_pressure_1.xvg")
mean1, std_e1 = get_mean_and_std_error(t, p1)
plt.plot(t,p1)
plt.plot(t[1:], mean1, color="Red", alpha=0.5)
plt.fill_between(t[1:], mean1-std_e1, mean1+std_e1, color="Red", alpha=0.1)
print("Final Pressure Estimate: {:.2f} +/- {:.2f} bar".format(mean1[-1], std_e1[-1]))
# Out:
# Final Pressure Estimate: -1404.75 +/- 44.20 bar

# %% [markdown]
# Negative pressure! What does that even mean?
#
# It means that there's not enough solvent. There aren't enough solvent molecules at this temperature to fill the space, so the space feels a negative pressure (it would collapse in on itself, if we didn't have periodic boundary conditions).
#
# We need to add more solvent to bring the pressure up.
#
# In normal simulations, we would use the NPT ensemble (constant number of particles, pressure, and temperature), keeping the pressure constant with a barostat by changing the box size (decreasing to increase pressure, increasing to decrease pressure). Here, though, we need to use the NVT ensemble, with constrant volume, becasue we need to keep the crystallographic symmetry by fixing the box size. This means we need to get the pressure up to atmospheric pressure on our own. We accomplish this by adding more waters.
#
# ### Adding additional solvent

# %%
# !gmx solvate -cp equilibration_1/equil_1.gro -cs spc216.gro -p supercell.top -o supercell_solvated_neutral_2.gro
# Out:
#                :-) GROMACS - gmx solvate, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx solvate -cp equilibration_1/equil_1.gro -cs spc216.gro -p supercell.top -o supercell_solvated_neutral_2.gro
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 6x6x7 boxes
# Solvent box contains 130962 atoms in 43654 residues
# Removed 13887 solvent atoms due to solvent-solvent overlap
# Removed 110610 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  2155 residues
# Generated solvent containing 6465 atoms in 2155 residues
# Writing generated configuration to supercell_solvated_neutral_2.gro
#
# Output configuration contains 128826 atoms in 23390 residues
# Volume                 :     1193.58 (nm^3)
# Density                :      1232.3 (g/l)
# Number of solvent molecules:   2155
#
# Processing topology
# Adding line for 2155 solvent molecules with resname (SOL) to topology file (supercell.top)
#
# Back Off! I just backed up supercell.top to ./#supercell.top.3#
#
# GROMACS reminds you: "What's the point, yo, what's the spread?" (Red Hot Chili Peppers)

# %%
# !gmx grompp -f mdp_files/min.mdp -c supercell_solvated_neutral_2.gro -p supercell.top -o min_2.tpr -maxwarn 2
# Out:
#                 :-) GROMACS - gmx grompp, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx grompp -f mdp_files/min.mdp -c supercell_solvated_neutral_2.gro -p supercell.top -o min_2.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file mdp_files/min.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to 2139057531
#
# WARNING 1 [file pdTp.itp, line 10]:
#   Atomtype CB was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# WARNING 2 [file pdTp.itp, line 15]:
#   Atomtype CR was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# Generated 2628 of the 2628 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 2619 of the 2628 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
# Analysing residue names:
# There are:  4352    Protein residues
# There are:   320        Ion residues
# There are:    32      Other residues
# There are: 18686      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 330417.00
#
# The largest distance between excluded atoms is 0.439 nm
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 84x84x108, spacing 0.115 0.115 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.15
#
# This run will generate roughly 10 Mb of data
#
# There was 1 note
#
# There were 2 warnings
#
# GROMACS reminds you: "Ease Myself Into the Body Bag" (P.J. Harvey)

# %%
# !gmx mdrun -s min_2.tpr -deffnm min_2
# Out:
#                 :-) GROMACS - gmx mdrun, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx mdrun -s min_2.tpr -deffnm min_2
#
# Compiled SIMD: SSE2, but for this host/run SSE4.1 might be better (see log).
# Reading file min_2.tpr, VERSION 2022.4-conda_forge (single precision)
# Using 1 MPI thread
# Using 10 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =         1000
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 1000.
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 1000 in 1001 steps.
# Potential Energy  = -1.9222540e+06
# Maximum force     =  1.4770903e+03 on atom 43615
# Norm of force     =  1.5745767e+01
#
# GROMACS reminds you: "Working in the Burger Kings, Spitting on your Onion Rings" (Slim Shady)

# %%
# !mkdir minimization_2; mv min_2.* minimization_2

# %%
# !echo 11 | gmx energy -f minimization_2/min_2.edr -o energy_2.xvg
# !mv energy_2.xvg minimization_2
# Out:
#                 :-) GROMACS - gmx energy, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx energy -f minimization_2/min_2.edr -o energy_2.xvg
#
# Opened minimization_2/min_2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Proper-Dih.      4  Improper-Dih.
#   5  Per.-Imp.-Dih.   6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pressure
#  13  Vir-XX          14  Vir-XY          15  Vir-XZ          16  Vir-YX
#  17  Vir-YY          18  Vir-YZ          19  Vir-ZX          20  Vir-ZY
#  21  Vir-ZZ          22  Pres-XX         23  Pres-XY         24  Pres-XZ
#  25  Pres-YX         26  Pres-YY         27  Pres-YZ         28  Pres-ZX
#  29  Pres-ZY         30  Pres-ZZ         31  #Surf*SurfTen   32  T-rest
#
# Last energy frame read 792 time 1000.000
#
# Statistics over 1001 steps [ 0.0000 through 1000.0000 ps ], 1 data sets
# All statistics are over 793 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                -1.85421e+06      38000     128776    -248465  (kJ/mol)
#
# GROMACS reminds you: "Working in the Burger Kings, Spitting on your Onion Rings" (Slim Shady)

# %%
t, E = get_data_from_xvg("minimization_2/energy_2.xvg")
plt.plot(t, E)

# %%
plt.semilogy(dE(t,E)[0], dE(t,E)[1])
print("Average abs change in energy for the last 50 steps: {} kJ/mol".format(np.mean(dE(t,E)[-1][-50:])))
# Out:
# Average abs change in energy for the last 50 steps: 57.32 kJ/mol

# %%
# !gmx grompp -f mdp_files/equil.mdp -c minimization_2/min_2.gro -p supercell.top -r supercell_solvated_neutral_2.gro -o equil_2.tpr -maxwarn 2
# !gmx mdrun -s equil_2.tpr -deffnm equil_2
# Out:
#                 :-) GROMACS - gmx grompp, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx grompp -f mdp_files/equil.mdp -c minimization_2/min_2.gro -p supercell.top -r supercell_solvated_neutral_2.gro -o equil_2.tpr -maxwarn 2
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file mdp_files/equil.mdp]:
#   Setting nstcalcenergy (100) equal to nstenergy (5)
#
# Setting the LD random seed to -218382370
#
# WARNING 1 [file pdTp.itp, line 10]:
#   Atomtype CB was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# WARNING 2 [file pdTp.itp, line 15]:
#   Atomtype CR was defined previously (e.g. in the forcefield files), and
#   has now been defined again. This could happen e.g. if you would use a
#   self-contained molecule .itp file that duplicates or replaces the
#   contents of the standard force-field files. You should check the contents
#   of your files and remove such repetition. If you know you should override
#   the previous definition, then you could choose to suppress this warning
#   with -maxwarn.
#
#
# Generated 2628 of the 2628 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 2619 of the 2628 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 3 bonded neighbours molecule type 'Protein'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'LIG'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Setting gen_seed to 2067791740
#
# Velocities were taken from a Maxwell distribution at 300 K
# Analysing residue names:
# There are:  4352    Protein residues
# There are:   320        Ion residues
# There are:    32      Other residues
# There are: 18686      Water residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group Protein is 177406.19
# Number of degrees of freedom in T-Coupling group non-Protein is 116306.81
#
# The largest distance between excluded atoms is 0.425 nm
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
#
# Calculated rlist for 1x1 atom pair-list as 1.025 nm, buffer size 0.025 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# NOTE 2 [file mdp_files/equil.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 64x64x80, spacing 0.152 0.152 0.159
#
# Estimate for the relative computational load of the PME mesh part: 0.12
#
# This run will generate roughly 308 Mb of data
#
# There were 2 notes
#
# There were 2 warnings
# GROMACS reminds you: "C is quirky, flawed, and an enourmous success." (Dennis Ritchie, C author)
#
#                 :-) GROMACS - gmx mdrun, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx mdrun -s equil_2.tpr -deffnm equil_2
#
# Compiled SIMD: SSE2, but for this host/run SSE4.1 might be better (see log).
# Reading file equil_2.tpr, VERSION 2022.4-conda_forge (single precision)
# Changing nstlist from 10 to 80, rlist from 1 to 1.101
#
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# starting mdrun 'Protein in water'
# 500 steps,      1.0 ps.
#
# Writing final coordinates.
#
#                Core t (s)   Wall t (s)        (%)
#        Time:      261.320       26.132     1000.0
#                  (ns/day)    (hour/ns)
# Performance:        3.313        7.244
#
# GROMACS reminds you: "Never replicate a successful experiment." (Fett's law.)

# %%
# !mkdir equilibration_2; mv equil_2.* equilibration_2

# %%
# !echo 19 | gmx energy -f equilibration_2/equil_2.edr -o equil_pressure_2.xvg
# !mv equil_pressure_2.xvg equilibration_2
# Out:
#                 :-) GROMACS - gmx energy, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx energy -f equilibration_2/equil_2.edr -o equil_pressure_2.xvg
#
# Opened equilibration_2/equil_2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Proper-Dih.      4  Improper-Dih.
#   5  Per.-Imp.-Dih.   6  LJ-14            7  Coulomb-14       8  LJ-(SR)
#   9  Disper.-corr.   10  Coulomb-(SR)    11  Coul.-recip.    12  Position-Rest.
#  13  Potential       14  Kinetic-En.     15  Total-Energy    16  Conserved-En.
#  17  Temperature     18  Pres.-DC        19  Pressure        20  Constr.-rmsd
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-Protein
#  41  T-non-Protein                       42  Lamb-Protein
#  43  Lamb-non-Protein
#
# Last energy frame read 100 time    1.000
#
# Statistics over 501 steps [ 0.0000 through 1.0000 ps ], 1 data sets
# All statistics are over 101 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    622.838        130    420.293    664.842  (bar)
#
# GROMACS reminds you: "Never replicate a successful experiment." (Fett's law.)

# %%
t, p2 = get_data_from_xvg("equilibration_2/equil_pressure_2.xvg")
mean2, std_e2 = get_mean_and_std_error(t, p2)
plt.plot(t,p2)
plt.plot(t[1:], mean2, color="Red", alpha=0.5)
plt.fill_between(t[1:], mean2-std_e2, mean2+std_e2, color="Red", alpha=0.1)
print("Final Pressure Estimate: {:.2f} +/- {:.2f} bar".format(mean2[-1], std_e2[-1]))
# Out:
# Final Pressure Estimate: 622.87 +/- 42.24 bar

# %% [markdown]
# ## Now we're close!
#
# In practice, you want longer minimizations (e.g. 5000-10,000 steps) and longer equilibrations (e.g. 10-100 ps) just to make sure everything is stable. But you can get the idea for what we're going even with these short runs.
#
# You basically want to add or remove solvent using the average pressure as a guide.
#
# For instance, our original solvated supercell had 16,531 waters, and the new one has 18,574 (1721 added) and the pressure went from -1275 to 446. We can find an estimate for the number of waters to add to bring us to 1 bar by linear interpolation:
#
# $P = \frac{P_{2}-P_{1}}{N_{w,2}-N_{w,1}} \ \mathrm{d}N_{w} + P_{1}$
#
# where $dN_{w}$ is the change in the number of total waters from the startin number.
#
# We want to set $P$ to 1 and solve for $N_{w}$ to get an estimate for how many waters to add or subtract in our next run.
#
# $ 1 = \frac{P_{2}-P_{1}}{N_{w,2}-N_{w,1}} \ \mathrm{d}N_{w} + P_{1} \rightarrow 1 - P_{1} = \frac{P_{2}-P_{1}}{N_{w,2}-N_{w,1}} \ \mathrm{d}N_{w} $
#
# $ \mathrm{d}N_{w} = \frac{(1 - P_{1})(N_{w,2}-N_{w,1})}{(P_{2}-P_{1})} $
#
# In our case, we added too many: if you plug in all the numbers, we get:

# %%
P1 = mean1[-1]
P2 = mean2[-1]

def get_num_waters(gro_file):
    with open(gro_file, 'r') as f:
        wat_atoms = 0
        for line in f.readlines():
            if "SOL" in line:
                wat_atoms += 1
                
    return int(wat_atoms/3)

Nw1 = get_num_waters("supercell_solvated_neutral.gro")
Nw2 = get_num_waters("supercell_solvated_neutral_2.gro")

dNw = int(((1-P1)*(Nw2-Nw1))/(P2-P1))

print("Total waters we need to add to the original solvated supercell: {}".format(dNw))
# Out:
# Total waters we need to add to the original solvated supercell: 1494

# %% [markdown]
# We keep doing this iterative process until the pressure +/- standard error is in the range (-100,100) bar. Then we're ready for production simulation!

# %% [markdown]
# ### The trajectory
#
# gmx `trjconv` converts the `.trr` trajectory file to another `.trr` trajectory file, but with the molecules mapped back, according to the periodic boundary conditions, so that the molecules are kept whole (`-pbc mol`).

# %%
# !echo 0 | gmx trjconv -f equilibration_2/equil_2.trr -s equilibration_2/equil_2.tpr -o equil_2_mol.trr -pbc mol
# !mv equil_2_mol.trr equilibration_2
# Out:
#                :-) GROMACS - gmx trjconv, 2022.4-conda_forge (-:
#
# Executable:   /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test/bin.SSE2/gmx
# Data prefix:  /Users/dwych/miniconda3_x86/miniconda3/envs/crystalMD_test
# Working dir:  /Users/dwych/Packages/lunus-data/crystalline_MD_prep
# Command line:
#   gmx trjconv -f equilibration_2/equil_2.trr -s equilibration_2/equil_2.tpr -o equil_2_mol.trr -pbc mol
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write trr: Trajectory in portable xdr format
# Reading file equilibration_2/equil_2.tpr, VERSION 2022.4-conda_forge (single precision)
# Reading file equilibration_2/equil_2.tpr, VERSION 2022.4-conda_forge (single precision)
# Select group for output
# Group     0 (         System) has 128826 elements
# Group     1 (        Protein) has 71232 elements
# Group     2 (      Protein-H) has 34944 elements
# Group     3 (        C-alpha) has  4352 elements
# Group     4 (       Backbone) has 13056 elements
# Group     5 (      MainChain) has 17440 elements
# Group     6 (   MainChain+Cb) has 21504 elements
# Group     7 (    MainChain+H) has 21664 elements
# Group     8 (      SideChain) has 49568 elements
# Group     9 (    SideChain-H) has 17504 elements
# Group    10 (    Prot-Masses) has 71232 elements
# Group    11 (    non-Protein) has 57594 elements
# Group    12 (            Ion) has   320 elements
# Group    13 (          Other) has  1216 elements
# Group    14 (             CA) has    32 elements
# Group    15 (            LIG) has  1216 elements
# Group    16 (             CL) has   288 elements
# Group    17 (          Water) has 56058 elements
# Group    18 (            SOL) has 56058 elements
# Group    19 (      non-Water) has 72768 elements
# Group    20 ( Water_and_ions) has 56378 elements
# Select a group: Selected 0: 'System'
# trr version: GMX_trn_file (single precision)
# Last frame        100 time    1.000    ->  frame      0 time    0.000       ->  frame      1 time    0.010       ->  frame      2 time    0.020       ->  frame      3 time    0.030       ->  frame      4 time    0.040       ->  frame      5 time    0.050       ->  frame      6 time    0.060       ->  frame      7 time    0.070       ->  frame      8 time    0.080       ->  frame      9 time    0.090       ->  frame     10 time    0.100       ->  frame     11 time    0.110       ->  frame     12 time    0.120       ->  frame     13 time    0.130       ->  frame     14 time    0.140       ->  frame     15 time    0.150       ->  frame     16 time    0.160       ->  frame     17 time    0.170       ->  frame     18 time    0.180       ->  frame     19 time    0.190       ->  frame     29 time    0.290       ->  frame     39 time    0.390       ->  frame     49 time    0.490       ->  frame     59 time    0.590       ->  frame     69 time    0.690       ->  frame     79 time    0.790       ->  frame     89 time    0.890       ->  frame     99 time    0.990
#  ->  frame    100 time    1.000
# Last written: frame    100 time    1.000
#
#
# GROMACS reminds you: "Hey, it's me - Pandora. Welcome to my new unboxing video!" (Anonymous)

# %%
import mdtraj as md
### DON'T DO THIS IN GENERAL WE JUST DON'T CARE ABOUT THE WARNINGS IN THIS CASE
import warnings
warnings.filterwarnings('ignore')
###############################################################################
traj = md.load("./equilibration_2/equil_2_mol.trr", top="./supercell_solvated_neutral_2.gro")

# %%
traj_view = ngl.show_mdtraj(traj)
traj_view.clear_representations()
traj_view.add_cartoon("protein")
traj_view.add_ball_and_stick("water", opacity=0.5)
traj_view.add_spacefill("name CL", color="yellow")
traj_view.add_point("not protein and not water and not name CL")
traj_view.camera = "orthographic"
traj_view
# Out:
# NGLWidget(max_frame=100)
